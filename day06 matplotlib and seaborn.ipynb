# %% [markdown]
# # Titanic Dataset — Exploratory Data Visualization
#
# This notebook explores the Titanic dataset using Matplotlib and Seaborn.
#
# ## Visualizations
# - Survival distribution
# - Age distribution
# - Fare vs Survival
# - Correlation heatmap
# - Fare distribution by passenger class
# - Survival by passenger class
# - Age vs Fare by survival

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
plt.title("Simple Line Plot")
plt.show()

# %%
plt.plot(x, y)

plt.title("Simple Line Plot")
plt.xlabel("X Values")
plt.ylabel("Y values")
plt.show()

# %%
import matplotlib.pyplot as plt

months = [1, 2, 3, 4, 5, 6]
sales = [100, 120, 115, 150, 170, 200]

plt.plot(months, sales)

plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.xticks(months)

plt.show()

# %%
x = [1, 2, 3, 4, 5]

y1 = [2, 4, 6, 8, 10]
y2 = [1, 3, 5, 7, 9]

plt.plot(x, y1)
plt.plot(x, y2)

plt.show()

# %%
plt.plot(x, y1, label="Even Numbers")
plt.plot(x, y2, label="Odd Numbers")

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
Months = [1, 2, 3, 4, 5, 6]
Sales = [100, 120, 115, 150, 170, 200]
plt.plot(Months,Sales,label="sales graph")
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Monthly sales")
# Out:
# Text(0.5, 1.0, 'Monthly sales')

# %%
import matplotlib.pyplot as plt

subjects = ["Python", "Java", "C++", "JavaScript"]
marks = [80, 60, 45, 70]

plt.bar(subjects, marks)
plt.show()

# %%
plt.plot(Months, Sales)

# %%
plt.barh(subjects, marks)

plt.xlabel("Subject")
plt.ylabel("Marks")
plt.title("Marks by Subject")

plt.show()

# %%
import matplotlib.pyplot as plt
languages = ["Python", "Java", "C++", "JavaScript"]
developers = [80, 50, 30, 65]
plt.bar(languages, developers, label="Developers")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

ages = [5, 12, 15, 18, 19, 21, 22, 23, 25, 30, 35, 40, 45, 50]

plt.hist(ages)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
plt.hist(
    ages,
    bins=5,
    edgecolor="black"
)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
import pandas as pd

df = pd.read_csv("train.csv")
ages = df["Age"].dropna()

plt.hist(ages, bins=10)

plt.title("Titanic Passenger Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")

plt.show()

# %%
plt.hist(ages, bins=5)
plt.show()

# %%
plt.hist(ages, bins=20)
plt.show()

# %%
df["Age"].isna().sum()
# Out:
# np.int64(177)

# %%
hours = [1, 2, 3, 4, 5]
marks = [40, 45, 55, 65, 80]
plt.scatter(hours, marks)

plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.title("Hours Studied vs Marks")

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2,2)

ax[0, 0].plot([1, 2, 3, 4], [10, 20, 15, 30])
ax[0, 1].bar(["A", "B", "C"], [10, 20, 15])
ax[1, 0].hist([10, 12, 14, 15, 18, 20, 20, 22])
ax[1, 1].scatter([1, 2, 3, 4], [5, 8, 6, 10])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Survived", data=df)

plt.title("Titanic Survival Distribution")
plt.xlabel("Survival Status")
plt.ylabel("Number of Passengers")

plt.show()

# %%
sns.countplot(x="Pclass", data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.scatterplot(data=df, x="Fare", y="Age")
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
sns.boxplot(data=df, x="Pclass", y="Fare")
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.histplot(x="Age", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True)

plt.title("Titanic Correlation Heatmap")

plt.show()

# %%
import pandas as pd

df = pd.read_csv("train.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True)

plt.title("Titanic Correlation Heatmap")

plt.show()

# %%
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.countplot(data=df, x="Pclass", hue="Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.scatterplot(
    data=df,
    x="Age",
    y="Fare",
    hue="Survived"
)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, x="Pclass", y="Fare")

plt.title("Fare Distribution by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")

plt.tight_layout()
plt.show()
